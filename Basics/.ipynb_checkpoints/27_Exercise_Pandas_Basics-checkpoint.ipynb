# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\Learning Data Analytics\Python\Luke's Tutorial\Python_Data_Analytics_Course-main\data_jobs.csv")

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Nigeria']).any()
# Out:
# np.True_

# %%
us_jobs = df[df['job_country'] == 'United States']

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].min()
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   35000.0
# Cloud Engineer                     42000.0
# Data Analyst                       25000.0
# Data Engineer                      23496.0
# Data Scientist                     30000.0
# Machine Learning Engineer          44408.5
# Senior Data Analyst                35360.0
# Senior Data Engineer               45000.0
# Senior Data Scientist              55000.0
# Software Engineer                  48982.0

# %%
#us_jobs.groupby('job_title_short')[['salary_year_avg']].describe()
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median','mean','min','max','count']).sort_values(by = 'median', ascending = False)
# Out:
#                              median           mean      min       max  count
# job_title_short
# Senior Data Scientist      155000.0  159330.432029  55000.0  475000.0   1241
# Machine Learning Engineer  150000.0  154240.382812  44408.5  315000.0    128
# Senior Data Engineer       150000.0  151448.023187  45000.0  375000.0   1058
# Data Scientist             130000.0  139946.707204  30000.0  960000.0   4553
# Software Engineer          130000.0  137964.929588  48982.0  375000.0    157
# Data Engineer              125000.0  134226.676753  23496.0  525000.0   2915
# Cloud Engineer             116100.0  120090.900000  42000.0  221844.0     20
# Senior Data Analyst        110000.0  115729.129954  35360.0  425000.0    913
# Business Analyst            90000.0   96175.447397  35000.0  387460.0    431
# Data Analyst                90000.0   94553.964924  25000.0  375000.0   4350

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].describe().sort_values(by = 'mean')
# Out:
#                             count           mean           std      min  \
# job_title_short
# Data Analyst               4350.0   94553.964924  33248.650655  25000.0
# Business Analyst            431.0   96175.447397  32570.729242  35000.0
# Senior Data Analyst         913.0  115729.129954  34769.663226  35360.0
# Cloud Engineer               20.0  120090.900000  45564.891468  42000.0
# Data Engineer              2915.0  134226.676753  42785.226304  23496.0
# Software Engineer           157.0  137964.929588  54015.437433  48982.0
# Data Scientist             4553.0  139946.707204  52791.742973  30000.0
# Senior Data Engineer       1058.0  151448.023187  36116.363829  45000.0
# Machine Learning Engineer   128.0  154240.382812  55573.192498  44408.5
# Senior Data Scientist      1241.0  159330.432029  48880.807732  55000.0
#
#                                  25%       50%       75%       max
# job_title_short
# Data Analyst                71262.50   90000.0  112500.0  375000.0
# ...
