# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\Learning Data Analytics\Python\Luke's Tutorial\Python_Data_Analytics_Course-main\data_jobs.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), float64(2), object(12)
# memory usage: 86.2+ MB

# %%
type(df['job_posted_date'][0])
# Out:
# str

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:00                  False                 False
# 1      2023-01-14 13:18:00                  False                 False
# 2      2023-10-10 13:14:00                  False                 False
# 3      2023-07-04 13:01:00                   True                 False
# 4      2023-08-07 14:29:00                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:00                  False                 False
# 785737 2023-03-12 06:18:00                  False                 False
# 785738 2023-03-12 06:32:00                  False                 False
# 785739 2023-03-12 06:32:00                  False                 False
# 785740 2023-03-13 06:16:00                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States         NaN              NaN              NaN
# 1              Mexico         NaN              NaN              NaN
# 2             Germany         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4               Sudan         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore         NaN              NaN              NaN
# 785737        Germany         NaN              NaN              NaN
# 785738       Malaysia         NaN              NaN              NaN
# 785739          Sudan         NaN              NaN              NaN
# 785740          India         NaN              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                     NaN
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:00                  False                 False
# 1      2023-01-14 13:18:00                  False                 False
# 2      2023-10-10 13:14:00                  False                 False
# 3      2023-07-04 13:01:00                   True                 False
# 4      2023-08-07 14:29:00                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:00                  False                 False
# 785737 2023-03-12 06:18:00                  False                 False
# 785738 2023-03-12 06:32:00                  False                 False
# 785739 2023-03-12 06:32:00                  False                 False
# 785740 2023-03-13 06:16:00                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States         NaN              NaN              NaN
# 1              Mexico         NaN              NaN              NaN
# 2             Germany         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4               Sudan         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore         NaN              NaN              NaN
# 785737        Germany         NaN              NaN              NaN
# 785738       Malaysia         NaN              NaN              NaN
# 785739          Sudan         NaN              NaN              NaN
# 785740          India         NaN              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills  job_posted_month
# 0                                                     NaN                 6
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...                 1
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...                10
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...                 7
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...                 8
# ...                                                   ...               ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...                 3
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...                 3
# 785738         {'analyst_tools': ['powerpoint', 'excel']}                 3
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...                 3
# 785740              {'cloud': ['aws'], 'other': ['flow']}                 3
#
# [785741 rows x 18 columns]

# %%
df.sort_values(by = 'job_posted_date', ascending = False, inplace = True)

# %%
df
# Out:
#                   job_title_short  \
# 90102   Machine Learning Engineer
# 112373        Senior Data Analyst
# 338569              Data Engineer
# 349026               Data Analyst
# 361195             Data Scientist
# ...                           ...
# 105399               Data Analyst
# 110290               Data Analyst
# 111440               Data Analyst
# 72158         Senior Data Analyst
# 108804               Data Analyst
#
#                                                 job_title  \
# 90102                                Intelligence analyst
# 112373  Marketing Data & Analytics Product Owner - Sen...
# 338569                                Azure data engineer
# 349026                                    Data internship
# 361195                                     Data scientist
# ...                                                   ...
# 105399     Technical Data Analyst / Designer -- 2207/2000
# 110290                                       Data Analyst
# 111440                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# 108804                                       Data Analyst
#
#                   job_location                      job_via  \
# 90102               Boston, MA               via Talent.com
# 112373  Boston, MA  (+1 other)  via Boston Consulting Group
# 338569              Austin, TX               via Talent.com
# 349026              Dallas, TX               via Talent.com
# 361195              Dallas, TX               via Talent.com
# ...                        ...                          ...
# 105399      Vandenberg AFB, CA                 via Tarta.ai
# 110290             Fairfax, VA            via CareerBuilder
# 111440       San Francisco, CA                     via Jora
# 72158            Worcester, MA                 via LinkedIn
# 108804            New York, NY            via CareerBuilder
#
#                job_schedule_type  job_work_from_home  \
# 90102                  Full-time               False
# 112373                 Full-time               False
# 338569                 Full-time               False
# 349026  Full-time and Internship               False
# 361195   Full-time and Temp work               False
# ...                          ...                 ...
# 105399                 Full-time               False
# 110290                 Full-time               False
# 111440                 Full-time               False
# 72158                  Full-time               False
# 108804                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 90102     New York, United States 2023-12-31 23:59:00                   True
# 112373    New York, United States 2023-12-31 23:59:00                  False
# 338569                      Sudan 2023-12-31 23:40:00                  False
# 349026                      Sudan 2023-12-31 23:40:00                  False
# 361195                      Sudan 2023-12-31 23:40:00                  False
# ...                           ...                 ...                    ...
# 105399  California, United States 2023-01-01 00:00:00                  False
# 110290    New York, United States 2023-01-01 00:00:00                  False
# 111440  California, United States 2023-01-01 00:00:00                   True
# 72158     New York, United States 2023-01-01 00:00:00                  False
# 108804    New York, United States 2023-01-01 00:00:00                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 90102                  False  United States         NaN              NaN
# 112373                 False  United States         NaN              NaN
# 338569                 False          Sudan         NaN              NaN
# 349026                 False          Sudan         NaN              NaN
# 361195                  True          Sudan         NaN              NaN
# ...                      ...            ...         ...              ...
# 105399                  True  United States         NaN              NaN
# 110290                 False  United States         NaN              NaN
# 111440                 False  United States         NaN              NaN
# 72158                   True  United States         NaN              NaN
# 108804                 False  United States         NaN              NaN
#
#         salary_hour_avg                    company_name  \
# 90102               NaN                VirtualVocations
# 112373              NaN         Boston Consulting Group
# 338569              NaN             RIT Solutions, Inc.
# 349026              NaN                Paramount Global
# 361195              NaN  Cognizant Technology Solutions
# ...                 ...                             ...
# 105399              NaN       Range Generation Next LLC
# 110290              NaN                         Protask
# 111440              NaN                           Adyen
# 72158               NaN          Atria Wealth Solutions
# 108804              NaN            Metasys Technologies
#
#                                                job_skills  \
# 90102                                                 NaN
# 112373  ['sql', 'python', 'r', 'gdpr', 'tableau', 'pow...
# 338569  ['sql', 'python', 'scala', 'java', 'azure', 'd...
# 349026                                                NaN
# 361195                                ['python', 'nosql']
# ...                                                   ...
# 105399                                  ['word', 'excel']
# 110290                                    ['sql', 'jira']
# 111440        ['r', 'python', 'sql', 'tableau', 'looker']
# 72158                        ['sql', 'atlassian', 'jira']
# 108804  ['sql', 'snowflake', 'visio', 'jira', 'conflue...
#
#                                           job_type_skills  job_posted_month
# 90102                                                 NaN                12
# 112373  {'analyst_tools': ['tableau', 'power bi'], 'li...                12
# 338569  {'cloud': ['azure', 'databricks'], 'libraries'...                12
# 349026                                                NaN                12
# 361195               {'programming': ['python', 'nosql']}                12
# ...                                                   ...               ...
# 105399               {'analyst_tools': ['word', 'excel']}                 1
# 110290        {'async': ['jira'], 'programming': ['sql']}                 1
# 111440  {'analyst_tools': ['tableau', 'looker'], 'prog...                 1
# 72158   {'async': ['jira'], 'other': ['atlassian'], 'p...                 1
# 108804  {'analyst_tools': ['visio'], 'async': ['jira',...                 1
#
# [785741 rows x 18 columns]

# %%
df.drop(columns = 'salary_hour_avg', inplace = True)
#df.drop(labels = 'salary_hour_avg', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df.drop(columns = 'salary_hour_avg', inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['salary_hour_avg'] not found in axis"

# %%
df
# Out:
#                   job_title_short  \
# 90102   Machine Learning Engineer
# 112373        Senior Data Analyst
# 338569              Data Engineer
# 349026               Data Analyst
# 361195             Data Scientist
# ...                           ...
# 105399               Data Analyst
# 110290               Data Analyst
# 111440               Data Analyst
# 72158         Senior Data Analyst
# 108804               Data Analyst
#
#                                                 job_title  \
# 90102                                Intelligence analyst
# 112373  Marketing Data & Analytics Product Owner - Sen...
# 338569                                Azure data engineer
# 349026                                    Data internship
# 361195                                     Data scientist
# ...                                                   ...
# 105399     Technical Data Analyst / Designer -- 2207/2000
# 110290                                       Data Analyst
# 111440                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# 108804                                       Data Analyst
#
#                   job_location                      job_via  \
# 90102               Boston, MA               via Talent.com
# 112373  Boston, MA  (+1 other)  via Boston Consulting Group
# 338569              Austin, TX               via Talent.com
# 349026              Dallas, TX               via Talent.com
# 361195              Dallas, TX               via Talent.com
# ...                        ...                          ...
# 105399      Vandenberg AFB, CA                 via Tarta.ai
# 110290             Fairfax, VA            via CareerBuilder
# 111440       San Francisco, CA                     via Jora
# 72158            Worcester, MA                 via LinkedIn
# 108804            New York, NY            via CareerBuilder
#
#                job_schedule_type  job_work_from_home  \
# 90102                  Full-time               False
# 112373                 Full-time               False
# 338569                 Full-time               False
# 349026  Full-time and Internship               False
# 361195   Full-time and Temp work               False
# ...                          ...                 ...
# 105399                 Full-time               False
# 110290                 Full-time               False
# 111440                 Full-time               False
# 72158                  Full-time               False
# 108804                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 90102     New York, United States 2023-12-31 23:59:00                   True
# 112373    New York, United States 2023-12-31 23:59:00                  False
# 338569                      Sudan 2023-12-31 23:40:00                  False
# 349026                      Sudan 2023-12-31 23:40:00                  False
# 361195                      Sudan 2023-12-31 23:40:00                  False
# ...                           ...                 ...                    ...
# 105399  California, United States 2023-01-01 00:00:00                  False
# 110290    New York, United States 2023-01-01 00:00:00                  False
# 111440  California, United States 2023-01-01 00:00:00                   True
# 72158     New York, United States 2023-01-01 00:00:00                  False
# 108804    New York, United States 2023-01-01 00:00:00                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 90102                  False  United States         NaN              NaN
# 112373                 False  United States         NaN              NaN
# 338569                 False          Sudan         NaN              NaN
# 349026                 False          Sudan         NaN              NaN
# 361195                  True          Sudan         NaN              NaN
# ...                      ...            ...         ...              ...
# 105399                  True  United States         NaN              NaN
# 110290                 False  United States         NaN              NaN
# 111440                 False  United States         NaN              NaN
# 72158                   True  United States         NaN              NaN
# 108804                 False  United States         NaN              NaN
#
#                           company_name  \
# 90102                 VirtualVocations
# 112373         Boston Consulting Group
# 338569             RIT Solutions, Inc.
# 349026                Paramount Global
# 361195  Cognizant Technology Solutions
# ...                                ...
# 105399       Range Generation Next LLC
# 110290                         Protask
# 111440                           Adyen
# 72158           Atria Wealth Solutions
# 108804            Metasys Technologies
#
#                                                job_skills  \
# 90102                                                 NaN
# 112373  ['sql', 'python', 'r', 'gdpr', 'tableau', 'pow...
# 338569  ['sql', 'python', 'scala', 'java', 'azure', 'd...
# 349026                                                NaN
# 361195                                ['python', 'nosql']
# ...                                                   ...
# 105399                                  ['word', 'excel']
# 110290                                    ['sql', 'jira']
# 111440        ['r', 'python', 'sql', 'tableau', 'looker']
# 72158                        ['sql', 'atlassian', 'jira']
# 108804  ['sql', 'snowflake', 'visio', 'jira', 'conflue...
#
#                                           job_type_skills  job_posted_month
# 90102                                                 NaN                12
# 112373  {'analyst_tools': ['tableau', 'power bi'], 'li...                12
# 338569  {'cloud': ['azure', 'databricks'], 'libraries'...                12
# 349026                                                NaN                12
# 361195               {'programming': ['python', 'nosql']}                12
# ...                                                   ...               ...
# 105399               {'analyst_tools': ['word', 'excel']}                 1
# 110290        {'async': ['jira'], 'programming': ['sql']}                 1
# 111440  {'analyst_tools': ['tableau', 'looker'], 'prog...                 1
# 72158   {'async': ['jira'], 'other': ['atlassian'], 'p...                 1
# 108804  {'analyst_tools': ['visio'], 'async': ['jira',...                 1
#
# [785741 rows x 17 columns]

# %%
df.dropna(subset = ['salary_year_avg'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 327439 to 108883
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
#  14  job_skills             20170 non-null  object
#  15  job_type_skills        20170 non-null  object
#  16  job_posted_month       22003 non-null  int32
# dtypes: bool(3), datetime64[ns](1), float64(1), int32(1), object(11)
# memory usage: 2.5+ MB
