# %% [markdown]
# **Arithmetic Operators**

# %%
2 + 3.0
# Out:
# 5.0

# %%
"What's " + "Up" + "!"
# Out:
# "What's Up!"

# %%
"What's Up " * 10
# Out:
# "What's Up What's Up What's Up What's Up What's Up What's Up What's Up What's Up What's Up What's Up "

# %%
3.0 - 2
# Out:
# 1.0

# %%
"What's Up" - "Up
# Out:
#   Cell In[7], line 1
#     "What's Up" - "Up
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
four = 4

four.__sub__(2)
# Out:
# 2

# %%
int.__sub__(4,3)
# Out:
# 1

# %%
4 - 2
# Out:
# 2

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
print('5 divided by 2 is: ', 5 // 2, 'with a remainder of', 5 % 2)
# Out:
# 5 divided by 2 is:  2 with a remainder of 1

# %%
min_salary = 20_000
max_salary = 80_000

avg_salary = (min_salary + max_salary) / 2
avg_salary
# Out:
# 50000.0

# %% [markdown]
# ### Assignment Operators

# %%
appicant_1 = 'Kelly'
applicant_2 = 'Luke'

# %%
appicant_1, applicant_2 = applicant_2, appicant_1

# %%
appicant_1, applicant_2
# Out:
# ('Luke', 'Kelly')

# %%
appicant_1 += applicant_2

# %%
appicant_1
# Out:
# 'LukeKellyKelly'

# %%
x = 1

x += 1

# %%
x
# Out:
# 2

# %%
x = 1

x *= 2

# %%
x
# Out:
# 2

# %% [markdown]
# ### Comparison Operators

# %%
salary_kelly = 60_000
salary_luke = 40_000

salary_kelly == salary_luke
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
if(salary_kelly > salary_luke):
    print('Kelly is more paid than Luke')
# Out:
# Kelly is more paid than Luke
