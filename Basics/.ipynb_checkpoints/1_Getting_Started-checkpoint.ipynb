# %%
"This is a coding cell"
# Out:
# 'This is a coding cell'

# %% [markdown]
# ## This is a markdown cell

# %%
2 + 2
# Out:
# 4

# %%
3 + 3
# Out:
# 6

# %%
2 + 2
3 * 3
# Out:
# 9

# %%
print(2 + 2)
print(3 * 3)
# Out:
# 4
# 9

# %%
print(2 + 2)
3 * 3
# Out:
# 4
# 9

# %%
3 * 3
print(2 + 2)
# Out:
# 4

# %%
# This is a comment

# %%
# This is a comment
2 + 2 #This adds 2 + 2
# Out:
# 4

# %% [markdown]
# This is a normal text

# %% [markdown]
# # Heading

# %% [markdown]
# **bold**

# %% [markdown]
# [Hockey site](https://www.scrapethissite.com/pages/forms/)

# %% [markdown]
# 1. one
# 2. two
# 3. three

# %%
# !ls #batch file
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %timeit [i**2 for i in range(1000)]
# Out:
# 218 μs ± 16.5 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n**2)
# Out:
# 303 μs ± 75.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
#Practice

# %%
# %timeit [i**2 for i in range(1000)]
# Out:
# 219 μs ± 33.1 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n**2)
# Out:
# 250 μs ± 14.3 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit [i ** 2 for i in range(1000)]
# Out:
# 74.2 μs ± 7.79 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
