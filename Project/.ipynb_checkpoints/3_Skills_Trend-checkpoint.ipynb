# %% [markdown]
# # How are in-demand skills trending for Data Analysts?

# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\Learning Data Analytics\Python\Luke's Tutorial\Python_Data_Analytics_Course-main\data_jobs.csv")

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
       return ast.literal_eval(skill_list)

df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()
df_DA_US
# Out:
#        job_title_short                                     job_title  \
# 36        Data Analyst                                  Data Analyst
# 68        Data Analyst                     Sr. Research Data Analyst
# 73        Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79        Data Analyst                    Data Analyst/Report Writer
# 93        Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# ...                ...                                           ...
# 785603    Data Analyst                           Junior Data Analyst
# 785626    Data Analyst                    Data Acquisition Associate
# 785685    Data Analyst                                  Data Analyst
# 785703    Data Analyst       Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst     Expert Business Data Analyst - Now Hiring
#
#             job_location               job_via job_schedule_type  \
# 36        Des Moines, IA       via Trabajo.org         Full-time
# ...

# %%
df_DA_US['job_posted_month'] = df['job_posted_date'].dt.month

# %%
df_DA_US_explode = df_DA_US.explode('job_skills')

# %%
df_DA_US_pivot = df_DA_US_explode.pivot_table(index = 'job_posted_month', columns = 'job_skills', aggfunc = 'size', fill_value  = 0)

# %%
df_DA_US_pivot.loc['Total'] = df_DA_US_pivot.sum()

# %%
df_DA_US_pivot = df_DA_US_pivot[df_DA_US_pivot.loc['Total'].sort_values(ascending = False).index]

# %%
#df_DA_US_pivot.drop('Total')
df_DA_US_pivot.iloc[:, 0:5]
# Out:
# job_skills          sql  excel  tableau  python    sas
# job_posted_month
# 1                  4601   3592     2488    2254   1832
# 2                  3168   2587     1676    1618   1212
# 3                  3226   2661     1804    1683   1238
# 4                  3220   2549     1789    1679   1302
# 5                  2581   2118     1432    1349    972
# 6                  2862   2382     1628    1609    984
# 7                  2609   2118     1533    1438    996
# 8                  3414   2731     1951    2025   1276
# 9                  2295   1801     1353    1229    856
# 10                 2574   1922     1429    1373    960
# 11                 2054   1533     1148    1049    792
# 12                 1848   1525     1080    1076    780
# Total             34452  27519    19311   18382  13200

# %%
DA_totals = df_DA_US.groupby('job_posted_month').size()
DA_totals
# Out:
# job_posted_month
# 1     8494
# 2     6124
# 3     6218
# 4     6049
# 5     4993
# 6     5683
# 7     5201
# 8     6634
# 9     4639
# 10    5271
# 11    4531
# 12    3979
# dtype: int64

# %%
df_DA_US_percent = df_DA_US_pivot.div(DA_totals/100, axis = 0)
df_DA_US_percent
# Out:
# job_skills              sql      excel    tableau     python        sas  \
# job_posted_month
# 1                 54.167648  42.288674  29.291264  26.536379  21.568166
# 2                 51.730895  42.243632  27.367734  26.420640  19.790986
# 3                 51.881634  42.795111  29.012544  27.066581  19.909939
# 4                 53.231939  42.139197  29.575136  27.756654  21.524219
# 5                 51.692369  42.419387  28.680152  27.017825  19.467254
# 6                 50.360725  41.914482  28.646841  28.312511  17.314799
# 7                 50.163430  40.722938  29.475101  27.648529  19.150163
# 8                 51.462165  41.166717  29.409105  30.524570  19.234248
# 9                 49.471869  38.823022  29.165768  26.492779  18.452253
# 10                48.833238  36.463669  27.110605  26.048188  18.212863
# 11                45.332156  33.833591  25.336570  23.151622  17.479585
# 12                46.443830  38.326213  27.142498  27.041970  19.602915
# ...

# %%
df_DA_US_percent = df_DA_US_percent.drop('Total')

# %%
# # changes month number to month name
df_DA_US_percent  = df_DA_US_percent.reset_index()
df_DA_US_percent
# df_DA_US_percent['job_posted_month_nm'] = df_DA_US_percent['job_posted_month'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
# # df_DA_US_percent = df_DA_US_percent.set_index('job_posted_month_nm')
# # df_DA_US_percent = df_DA_US_percent.drop(columns='job_posted_month')
# Out:
# job_skills  job_posted_month        sql      excel    tableau     python  \
# 0                          1  54.167648  42.288674  29.291264  26.536379
# 1                          2  51.730895  42.243632  27.367734  26.420640
# 2                          3  51.881634  42.795111  29.012544  27.066581
# 3                          4  53.231939  42.139197  29.575136  27.756654
# 4                          5  51.692369  42.419387  28.680152  27.017825
# 5                          6  50.360725  41.914482  28.646841  28.312511
# 6                          7  50.163430  40.722938  29.475101  27.648529
# 7                          8  51.462165  41.166717  29.409105  30.524570
# 8                          9  49.471869  38.823022  29.165768  26.492779
# 9                         10  48.833238  36.463669  27.110605  26.048188
# 10                        11  45.332156  33.833591  25.336570  23.151622
# 11                        12  46.443830  38.326213  27.142498  27.041970
#
# ...

# %%
df_DA_US_percent['job_posted_month_nm'] = df_DA_US_percent['job_posted_month'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))

# %%
df_DA_US_percent
# Out:
# job_skills  job_posted_month        sql      excel    tableau     python  \
# 0                          1  54.167648  42.288674  29.291264  26.536379
# 1                          2  51.730895  42.243632  27.367734  26.420640
# 2                          3  51.881634  42.795111  29.012544  27.066581
# 3                          4  53.231939  42.139197  29.575136  27.756654
# 4                          5  51.692369  42.419387  28.680152  27.017825
# 5                          6  50.360725  41.914482  28.646841  28.312511
# 6                          7  50.163430  40.722938  29.475101  27.648529
# 7                          8  51.462165  41.166717  29.409105  30.524570
# 8                          9  49.471869  38.823022  29.165768  26.492779
# 9                         10  48.833238  36.463669  27.110605  26.048188
# 10                        11  45.332156  33.833591  25.336570  23.151622
# 11                        12  46.443830  38.326213  27.142498  27.041970
#
# ...

# %%
df_DA_US_percent = df_DA_US_percent.set_index('job_posted_month_nm')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2576\1923360235.py in ?()
# ----> 1 df_DA_US_percent = df_DA_US_percent.set_index('job_posted_month_nm')
#       2 df_DA_US_percent
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['job_posted_month_nm'] are in the columns"

# %%
df_DA_US_percent
# Out:
# job_skills           job_posted_month        sql      excel    tableau  \
# job_posted_month_nm
# Jan                                 1  54.167648  42.288674  29.291264
# Feb                                 2  51.730895  42.243632  27.367734
# Mar                                 3  51.881634  42.795111  29.012544
# Apr                                 4  53.231939  42.139197  29.575136
# May                                 5  51.692369  42.419387  28.680152
# Jun                                 6  50.360725  41.914482  28.646841
# Jul                                 7  50.163430  40.722938  29.475101
# Aug                                 8  51.462165  41.166717  29.409105
# Sep                                 9  49.471869  38.823022  29.165768
# Oct                                10  48.833238  36.463669  27.110605
# Nov                                11  45.332156  33.833591  25.336570
# Dec                                12  46.443830  38.326213  27.142498
#
# ...

# %%
df_DA_US_percent = df_DA_US_percent.drop(columns='job_posted_month')

# %%
df_plot = df_DA_US_percent.iloc[:,:5]

# %%
sns.set_theme(style = 'ticks')
sns.lineplot(data = df_plot,dashes = False, palette = 'tab10')
plt.title('Trending Top Skills for Data Analyst in the US')
sns.despine()
plt.ylabel('Likelihoood in Job Posting')
plt.xlabel('2023')
plt.legend().remove()

# add percentage to the y axis
from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(PercentFormatter(decimals = 0))

for i in range(5):
    plt.text(11.2, df_plot.iloc[-1, i], df_plot.columns[i])
