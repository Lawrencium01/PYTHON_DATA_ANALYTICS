# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\Learning Data Analytics\Python\Luke's Tutorial\Python_Data_Analytics_Course-main\data_jobs.csv")

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)

df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
import seaborn as sns

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()
df_DA_US = df_DA_US.dropna(subset = ['salary_year_avg'])

# %%
df_DA_US
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 782637    Data Analyst                     Data Integration Analyst
# 782798    Data Analyst                       Reference Data Analyst
# 783588    Data Analyst                       Data Analytics Manager
# 783866    Data Analyst              Lead Credit Bureau Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
#
#               job_location                job_via job_schedule_type  \
# 109               Anywhere             via Get.It         Full-time
# ...

# %%
df_DA_US = df_DA_US.explode('job_skills')
df_DA_US
# Out:
#        job_title_short                              job_title   job_location  \
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 180       Data Analyst                       Data Analyst III  Dos Palos, CA
# ...                ...                                    ...            ...
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
#
# ...

# %%
# df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['size','median'])
df_DA_US_group = df_DA_US.groupby('job_skills').agg(
    skill_count = ('job_skills','count'),
    median_salary = ('salary_year_avg', 'median')
)
df_DA_US_group
# Out:
#             skill_count  median_salary
# job_skills
# airflow              44      116250.00
# airtable              5       90000.00
# alteryx             106      106281.25
# angular               8      107500.00
# ansible               1      159640.00
# ...                 ...            ...
# wire                  4       74250.00
# word                461       81194.75
# workfront             3       75000.00
# wrike                 1       75000.00
# zoom                 15       80740.00
#
# [170 rows x 2 columns]

# %%
df_DA_top_pay = df_DA_US_group.sort_values('median_salary', ascending = False).head(10)
df_DA_top_pay
# Out:
#               skill_count  median_salary
# job_skills
# dplyr                   2       196250.0
# bitbucket               3       189000.0
# gitlab                  3       186000.0
# solidity                1       179000.0
# hugging face            1       175000.0
# couchbase               1       160515.0
# ansible                 1       159640.0
# mxnet                   2       149000.0
# cassandra               6       148250.0
# vmware                  1       147500.0

# %%
df_DA_skills = df_DA_US_group.sort_values('skill_count', ascending = False).head(10)
df_DA_skills = df_DA_skills.sort_values('median_salary', ascending = False)
df_DA_skills
# Out:
#             skill_count  median_salary
# job_skills
# python             1431       97500.00
# tableau            1364       92875.00
# r                   893       92500.00
# sql server          286       92500.00
# sql                2508       91000.00
# sas                 926       90000.00
# power bi            838       90000.00
# powerpoint          462       85000.00
# excel              1808       84392.00
# word                461       81194.75

# %%
fig, ax = plt.subplots(2,1)

df_DA_top_pay.plot(kind = 'barh', y = 'median_salary', ax = ax[0])
ax[0].set_title('Top 10 Highest Paid Skills for Data Analysts')
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].invert_yaxis()
ax[0].legend().set_visible(False)
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"${int(x/1000)}K"))

df_DA_skills.plot(kind = 'barh', y = 'median_salary', ax = ax[1])
ax[1].set_title('Top 10 Most In-Demand Skills for Data Analysts')
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary ($USD)')
ax[1].invert_yaxis()
ax[1].legend().set_visible(False)
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"${int(x/1000)}K"))

ax[1].set_xlim(0, 200000)
#ax[1].set_xlim(ax[0].get_xlim())
plt.tight_layout()
#fig.tight_layout()
plt.show()

# %%
    fig, ax = plt.subplots(2,1)
    
    sns.set_theme(style = 'ticks')
    
    # df_DA_top_pay.plot(kind = 'barh', y = 'median_salary', ax = ax[0])
    
    sns.barplot(data = df_DA_top_pay, x = 'median_salary', y = 'job_skills', ax = ax[0], hue = 'median_salary', palette = 'dark:b_r')
    ax[0].set_title('Top 10 Highest Paid Skills for Data Analysts')
    ax[0].set_ylabel('')
    ax[0].set_xlabel('')
    # ax[0].invert_yaxis()
    ax[0].legend().set_visible(False)
    ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"${int(x/1000)}K"))
    
    # df_DA_skills.plot(kind = 'barh', y = 'skill_count', ax = ax[1])
    
    sns.barplot(data = df_DA_skills, x = 'median_salary', y = 'job_skills', ax = ax[1], hue = 'median_salary', palette = 'light:b')
    ax[1].set_title('Top 10 Most In-Demand Skills for Data Analysts')
    ax[1].set_ylabel('')
    ax[1].set_xlabel('Median Salary ($USD)')
    # ax[1].invert_yaxis()
    ax[1].legend().set_visible(False)
    #ax[1].legend().remove()
    ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"${int(x/1000)}K"))
    
    ax[1].set_xlim(0, 200000)
    #ax[1].set_xlim(ax[0].get_xlim())
    plt.tight_layout()
    #fig.tight_layout()
    plt.show()

# %%
df_DA_US['salary_year_avg'].plot(kind = 'hist', bins = 40, edgecolor = 'black')

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"${int(x/1000)}K"))

plt.xlim(0, 250000)
plt.title('Distribution of United States Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary')
plt.ylabel('Number of Jobs')
plt.show()

# %%
# df_DA_US['salary_year_avg'].plot(kind = 'hist', bins = 40, edgecolor = 'black')

sns.distplot(df_DA_US['salary_year_avg'])

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"${int(x/1000)}K"))

plt.xlim(0, 250000)
plt.title('Distribution of United States Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary')
plt.ylabel('Number of Jobs')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7356\3138135130.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_DA_US['salary_year_avg'])

# %%
job_titles = ['Data Analyst', 'Data Scientist', 'Data Engineer']

df_US = df[(df['job_title_short'].isin(job_titles)) & (df['job_country'] == 'United States')].copy()

df_US = df_US.dropna(subset = ['salary_year_avg'])

job_list = [df_US[df_US['job_title_short'] == job_title]['salary_year_avg']for job_title in job_titles]

plt.boxplot(job_list, labels=job_titles, vert=False)
plt.title('Salary Distribution in the United States')
plt.xlabel('Yearly Salary ($USD)')
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"${int(x/1000)}K"))
plt.xlim(0,600000)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7356\2702631131.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(job_list, labels=job_titles, vert=False)

# %%
sns.boxplot(data = df_US, x = 'salary_year_avg', y = 'job_title_short')

plt.title('Salary Distribution in the United States')
plt.xlabel('Yearly Salary ($USD)')
plt.ylabel('')
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"${int(x/1000)}K"))
plt.xlim(0,600000)
plt.show()
