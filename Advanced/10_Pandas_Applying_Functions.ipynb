# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\Learning Data Analytics\Python\Luke's Tutorial\Python_Data_Analytics_Course-main\data_jobs.csv")

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df[df['salary_year_avg'].notna()]['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
help(df.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(
#     func: 'AggFuncType',
#     axis: 'Axis' = 0,
#     raw: 'bool' = False,
#     result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None,
#     args=(),
#     by_row: "Literal[False, 'compat']" = 'compat',
#     engine: "Literal['python', 'numba']" = 'python',
#     engine_kwargs: 'dict[str, bool] | None' = None,
#     **kwargs
# ) method of pandas.core.frame.DataFrame instance
#     Apply a function along an axis of the DataFrame.
#
#     Objects passed to the function are Series objects whose index is
#     either the DataFrame's index (``axis=0``) or the DataFrame's columns
#     (``axis=1``). By default (``result_type=None``), the final return type
#     is inferred from the return type of the applied function. Otherwise,
#     it depends on the `result_type` argument.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column or row.
# ...

# %%
df_salary = df[df['salary_year_avg'].notna()].copy()

def projected_salary(salary):
    return salary * 1.03

df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(projected_salary)

df_salary[['salary_year_avg','salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary: salary * 1.03)

df_salary[['salary_year_avg','salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'] * 1.03

df_salary[['salary_year_avg','salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
type(df['job_skills'][1])
# Out:
# str

# %%
import ast

#df['job_skills'] = ast.literal_eval(df['job_skills']) doesnt work

def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)

df['job_skills'] = df['job_skills'].apply(clean_list)
df['job_skills']
# Out:
# 0                                                      None
# 1                [r, python, sql, nosql, power bi, tableau]
# 2         [python, sql, c#, azure, airflow, dax, docker,...
# 3         [python, c++, java, matlab, aws, tensorflow, k...
# 4         [bash, python, oracle, aws, ansible, puppet, j...
#                                 ...
# 785736    [bash, python, perl, linux, unix, kubernetes, ...
# 785737                               [sas, sas, sql, excel]
# 785738                                  [powerpoint, excel]
# 785739    [python, go, nosql, sql, mongo, shell, mysql, ...
# 785740                                          [aws, flow]
# Name: job_skills, Length: 785741, dtype: object

# %%
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
def projected_salary(row):
    if "Senior" in df_salary['job_title_short']:
        return row['salary_year_avg'] * 1.05
    else:
        return row['salary_year_avg'] * 1.03

df_salary['salary_year_inflated'] = df_salary.apply(projected_salary, axis = 1)
df_salary[['job_title_short','salary_year_avg','salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %%
df_salary['salary_year_inflated'] = df_salary.apply(lambda row: row['salary_year_avg'] * 1.05 if 'Senior' in df_salary['job_title_short'] else row['salary_year_avg'] * 1.03, axis = 1)
df_salary[['job_title_short','salary_year_avg','salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %% [markdown]
# ## Practice

# %%
def deflated_salary(salary):
    return salary * 0.97
    
df_salary['salary_year_deflated'] = df['salary_year_avg'].apply(deflated_salary)
df_salary[['salary_year_avg','salary_year_deflated']]
# Out:
#         salary_year_avg  salary_year_deflated
# 28             109500.0             106215.00
# 77             140000.0             135800.00
# 92             120000.0             116400.00
# 100            228222.0             221375.34
# 109             89000.0              86330.00
# ...                 ...                   ...
# 785624         139216.0             135039.52
# 785641         150000.0             145500.00
# 785648         221875.0             215218.75
# 785682         157500.0             152775.00
# 785692         157500.0             152775.00
#
# [22003 rows x 2 columns]

# %%
def deflated_salary(row):
    if 'Senior' in row['job_title_short']:
        return row['salary_year_avg'] * 0.95
    else:
       return row['salary_year_avg'] * 0.97

df_salary['salary_year_deflated'] = df_salary.apply(deflated_salary, axis = 1)
df_salary[['job_title_short','salary_year_avg','salary_year_deflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_deflated
# 28      Data Scientist         109500.0             106215.00
# 77       Data Engineer         140000.0             135800.00
# 92       Data Engineer         120000.0             116400.00
# 100     Data Scientist         228222.0             221375.34
# 109       Data Analyst          89000.0              86330.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             135039.52
# 785641   Data Engineer         150000.0             145500.00
# 785648  Data Scientist         221875.0             215218.75
# 785682  Data Scientist         157500.0             152775.00
# 785692  Data Scientist         157500.0             152775.00
#
# [22003 rows x 3 columns]
