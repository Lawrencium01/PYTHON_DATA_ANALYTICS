# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\Learning Data Analytics\Python\Luke's Tutorial\Python_Data_Analytics_Course-main\data_jobs.csv")

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
       return ast.literal_eval(skill_list)

df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst']
df_DA
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# 12                      Lyon, France
# 18                    Warsaw, Poland
# 31                     Paris, France
# 34                 Erlangen, Germany
# ...                              ...
# 785703                      Anywhere
# 785705                   Oakland, CA
# 785715                         India
# 785717                Erfurt, Jerman
# 785737            Bad Rodach, Jerman
#
#                                                   job_via  \
# 1                                        via BeBee México
# 12                                           via Jobijoba
# 18                                  via Praca Trabajo.org
# 31                                           via LinkedIn
# 34                        via Central Illinois Proud Jobs
# ...                                                   ...
# 785703                                       via Snagajob
# 785705                                       via Snagajob
# 785715  melalui Jobsleworld - Jobs In India - Job Vaca...
# 785717                                   melalui LinkedIn
# 785737                          melalui BeBee Deutschland
#
#                job_schedule_type  job_work_from_home  \
# 1                      Full-time               False
# 12      Full-time and Internship               False
# 18                     Full-time               False
# 31      Full-time and Internship               False
# 34                     Full-time               False
# ...                          ...                 ...
# 785703                 Full-time                True
# 785705                 Full-time               False
# 785715           Pekerjaan tetap               False
# 785717           Pekerjaan tetap               False
# 785737           Pekerjaan tetap               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 1                          Mexico 2023-01-14 13:18:00                  False
# 12                         France 2023-12-22 13:24:00                  False
# 18                         Poland 2023-10-16 13:36:00                  False
# 31                         France 2023-10-19 13:59:00                  False
# 34                        Germany 2023-02-23 13:31:00                   True
# ...                           ...                 ...                    ...
# 785703       Texas, United States 2023-01-28 06:02:00                   True
# 785705  California, United States 2023-01-09 06:00:00                  False
# 785715                      India 2023-03-13 06:16:00                  False
# 785717                    Germany 2023-03-12 06:18:00                  False
# 785737                    Germany 2023-03-12 06:18:00                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 1                      False         Mexico         NaN              NaN
# 12                     False         France         NaN              NaN
# 18                     False         Poland         NaN              NaN
# 31                     False         France         NaN              NaN
# 34                     False        Germany         NaN              NaN
# ...                      ...            ...         ...              ...
# 785703                 False  United States         NaN              NaN
# 785705                 False  United States         NaN              NaN
# 785715                 False          India         NaN              NaN
# 785717                 False        Germany         NaN              NaN
# 785737                 False        Germany         NaN              NaN
#
#         salary_hour_avg                                       company_name  \
# 1                   NaN                         Hewlett Packard Enterprise
# 12                  NaN                                              Engie
# 18                  NaN                                              Glovo
# 31                  NaN  GROUPE BON MARCHÉ : Le Bon Marché Rive Gauche ...
# 34                  NaN                                       DEFACTO GmbH
# ...                 ...                                                ...
# 785703              NaN                        Axelon Services Corporation
# 785705              NaN                                   PG&E Corporation
# 785715              NaN                                               Amul
# 785717              NaN                                      NTT DATA DACH
# 785737              NaN                                   HABA FAMILYGROUP
#
#                                                job_skills  \
# 1              [r, python, sql, nosql, power bi, tableau]
# 12                 [sql, php, excel, power bi, sap, jira]
# 18      [sql, python, r, redshift, pandas, excel, look...
# 31                                                  [sql]
# 34                                                  [sap]
# ...                                                   ...
# 785703                                               None
# 785705                             [sql, python, tableau]
# 785715                                               None
# 785717                                       [aws, azure]
# 785737                             [sas, sas, sql, excel]
#
#                                           job_type_skills
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 12      {'analyst_tools': ['excel', 'power bi', 'sap']...
# 18      {'analyst_tools': ['excel', 'looker', 'tableau...
# 31                               {'programming': ['sql']}
# 34                             {'analyst_tools': ['sap']}
# ...                                                   ...
# 785703                                                NaN
# 785705  {'analyst_tools': ['tableau'], 'programming': ...
# 785715                                                NaN
# 785717                        {'cloud': ['aws', 'azure']}
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
#
# [196075 rows x 17 columns]

# %%
df_explode = df_DA.explode('job_skills')

# %%
df_explode['job_posted_month_no'] = df_explode['job_posted_date'].dt.month

# %%
df_pivot = df_explode.pivot_table(index = 'job_posted_month_no', columns = 'job_skills', aggfunc = 'size', fill_value = 0)

# %%
df_pivot.loc['Total'] =  df_pivot.sum()
df_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# 12                       144        10      274       28           0       13
# Total                   2002        88     4570      376           2      186
#
# job_skills           apl  arch  asana  asp.net  ...  webex  windows  wire  \
# job_posted_month_no                             ...
# 1                      2     1     29       34  ...     17      228     6
# 2                      1     4     27       13  ...      9      202     6
# 3                      6     1     17       13  ...      8      194     8
# 4                      8     9      9       15  ...      9      185    14
# 5                      9     2      8       21  ...     11      122     3
# 6                      9     4     16       16  ...      8      157    14
# 7                      5     8     19       12  ...      5      161    11
# 8                     10     3     13       12  ...      9      184    11
# 9                      3    10     12       10  ...      4      150     8
# 10                     0     8     11       14  ...      4      156     8
# 11                     0     5      4       12  ...      4      144     4
# 12                     0     8     11        9  ...      6      139     8
# Total                 53    63    176      181  ...     94     2022   101
#
# job_skills            word  workfront  wrike  wsl  xamarin  yarn  zoom
# job_posted_month_no
# 1                     1778          0     11    6        0     9    95
# 2                     1235          4      2    5        0     4    41
# 3                     1203          1      1    3        1     5    45
# 4                     1177          8      2    1        0     6    26
# 5                      957          3      4    0        0     7    18
# 6                     1237          6      6    0        0    11    34
# 7                     1069          0      3    0        0     6    38
# 8                     1298          0      1    0        0    11    41
# 9                      945          0      1    0        0     5    25
# 10                     990          5      2    0        1     4    39
# 11                     887          1      1    1        0     6    26
# 12                     786          3      5    0        0     2    37
# Total                13562         31     39   16        2    76   465
#
# [13 rows x 235 columns]

# %%
df_pivot = df_pivot[df_pivot.loc['Total'].sort_values(ascending = False).index]
df_pivot = df_pivot.drop('Total')

# %%
df_pivot.iloc[0:, 0:5].plot(
    kind = 'line',
    linewidth = 4,
    linestyle = ':', #'.','-','--'
    colormap = 'viridis',
    marker = 'o',
    markersize = 5,
    figsize = (10,5)
)
plt.title('Top 5 skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
#df_explode.groupby('job_skills')['salary_year_avg'].agg(['size','median'])
skill_stats = df_explode.groupby('job_skills').agg(
    skill_count = ('job_skills', 'count'),
    medain_salary = ('salary_year_avg', 'median')
)

skill_stats = skill_stats.sort_values('skill_count', ascending = False).head(20)
skill_stats
# Out:
#             skill_count  medain_salary
# job_skills
# sql               92428     92500.0000
# excel             66860     84479.0000
# python            57190     98500.0000
# tableau           46455     95000.0000
# power bi          39380     90000.0000
# r                 29996     92527.5000
# sas               27998     90000.0000
# powerpoint        13822     85000.0000
# word              13562     80000.0000
# sap               11280     90000.0000
# azure             10913    100000.0000
# oracle            10387     95000.0000
# aws                9047    100500.0000
# sql server         8288     92150.0000
# go                 7905     90000.0000
# flow               7259     94450.0000
# vba                6841     90000.0000
# looker             6259    104000.0000
# snowflake          6178    110240.1094
# qlik               5681    100000.0000

# %%
from adjustText import adjust_text

skill_stats.plot(kind = 'scatter', x = 'skill_count', y = 'medain_salary')

texts = []

for i, txt in enumerate(skill_stats.index):
    texts.append(plt.text(skill_stats['skill_count'].iloc[i],skill_stats['medain_salary'].iloc[i], txt))

adjust_text(texts, arrowprops = dict(arrowstyle="->", color = 'grey', lw = 1))

ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f"${int(y/1000)}K"))

plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary ($USD)')
plt.title('Salary vs Count of Job Posting for Top 10 Skills')
plt.tight_layout() 
    
plt.show()

# %%
#!pip install adjustText
